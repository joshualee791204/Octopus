# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
##load train data
raw_train = pd.read_csv('train.csv')
df=raw_train.copy()

# %%
#This funtion plot the relationshipn between y and other variables. Float, int, or str use different types of plots
from Individual_Variables_Analysis import summary_indetail as summ
def plot_saleprice_vars(df,range_index):
    plt.close('all')
    try:
        for i in range_index:
            if type(df.iloc[:,i].dropna().values[0]) is np.float64:
                data=pd.concat([df.SalePrice, df.iloc[:,i]], axis=1)
                plt.figure(i+1)
                data.plot.scatter(x=df.columns[i], y="SalePrice", ylim=(0,800000))
                plt.title("Number of NAs is %i" % (1460-summ(df).loc[summ(df).name==df.columns[i]].num_not_NAs))
            else:
                if type(df.iloc[:,i].dropna().values[0]) is np.int64:
                    data=pd.concat([df.SalePrice, df.iloc[:,i]], axis=1)
                    plt.figure(i+1)
                    data.plot.scatter(x=df.columns[i], y="SalePrice", ylim=(0,800000))
                    plt.title("Number of NAs is %i" % (1460-summ(df).loc[summ(df).name==df.columns[i]].num_not_NAs))
                else:
                    data=pd.concat([df.SalePrice, df.iloc[:,i]], axis=1)
                    plt.figure(i+1)
                    sns.boxplot(x=df.columns[i], y='SalePrice', data=data)
                    plt.title("Number of NAs is %i" % (1460-summ(df).loc[summ(df).name==df.columns[i]].num_not_NAs))
        plt.show()
    except:
        print("Error: index out of range")

# %%
plot_saleprice_vars(df,range(74,78))

# %%
corrmap = df.corr()
f, ax = plt.subplots(figsize=(16,12))
sns.heatmap(corrmap, vmax=0.8, square=True)

# %%
##from the bottom line in this heatmap. 'OverallQual','GrLiveArea', 'GarageArea',

# %%
pd.set_option('display.max_rows', 100)

# %%
summ(df)
# Out:
#              name                     type  num_not_NAs  num_dupl
# 0              Id    <class 'numpy.int64'>         1460      1460
# 1      MSSubClass    <class 'numpy.int64'>         1460        15
# 2        MSZoning            <class 'str'>         1460         5
# 3     LotFrontage  <class 'numpy.float64'>         1201       110
# 4         LotArea    <class 'numpy.int64'>         1460      1073
# 5          Street            <class 'str'>         1460         2
# 6           Alley            <class 'str'>           91         2
# 7        LotShape            <class 'str'>         1460         4
# 8     LandContour            <class 'str'>         1460         4
# 9       Utilities            <class 'str'>         1460         2
# 10      LotConfig            <class 'str'>         1460         5
# 11      LandSlope            <class 'str'>         1460         3
# 12   Neighborhood            <class 'str'>         1460        25
# 13     Condition1            <class 'str'>         1460         9
# 14     Condition2            <class 'str'>         1460         8
# 15       BldgType            <class 'str'>         1460         5
# 16     HouseStyle            <class 'str'>         1460         8
# 17    OverallQual    <class 'numpy.int64'>         1460        10
# 18    OverallCond    <class 'numpy.int64'>         1460         9
# 19      YearBuilt    <class 'numpy.int64'>         1460       112
# 20   YearRemodAdd    <class 'numpy.int64'>         1460        61
# 21      RoofStyle            <class 'str'>         1460         6
# 22       RoofMatl            <class 'str'>         1460         8
# 23    Exterior1st            <class 'str'>         1460        15
# 24    Exterior2nd            <class 'str'>         1460        16
# 25     MasVnrType            <class 'str'>         1452         4
# 26     MasVnrArea  <class 'numpy.float64'>         1452       327
# 27      ExterQual            <class 'str'>         1460         4
# 28      ExterCond            <class 'str'>         1460         5
# 29     Foundation            <class 'str'>         1460         6
# 30       BsmtQual            <class 'str'>         1423         4
# 31       BsmtCond            <class 'str'>         1423         4
# 32   BsmtExposure            <class 'str'>         1422         4
# 33   BsmtFinType1            <class 'str'>         1423         6
# 34     BsmtFinSF1    <class 'numpy.int64'>         1460       637
# 35   BsmtFinType2            <class 'str'>         1422         6
# 36     BsmtFinSF2    <class 'numpy.int64'>         1460       144
# 37      BsmtUnfSF    <class 'numpy.int64'>         1460       780
# 38    TotalBsmtSF    <class 'numpy.int64'>         1460       721
# 39        Heating            <class 'str'>         1460         6
# 40      HeatingQC            <class 'str'>         1460         5
# 41     CentralAir            <class 'str'>         1460         2
# 42     Electrical            <class 'str'>         1459         5
# 43       1stFlrSF    <class 'numpy.int64'>         1460       753
# 44       2ndFlrSF    <class 'numpy.int64'>         1460       417
# 45   LowQualFinSF    <class 'numpy.int64'>         1460        24
# 46      GrLivArea    <class 'numpy.int64'>         1460       861
# 47   BsmtFullBath    <class 'numpy.int64'>         1460         4
# 48   BsmtHalfBath    <class 'numpy.int64'>         1460         3
# 49       FullBath    <class 'numpy.int64'>         1460         4
# 50       HalfBath    <class 'numpy.int64'>         1460         3
# 51   BedroomAbvGr    <class 'numpy.int64'>         1460         8
# 52   KitchenAbvGr    <class 'numpy.int64'>         1460         4
# 53    KitchenQual            <class 'str'>         1460         4
# 54   TotRmsAbvGrd    <class 'numpy.int64'>         1460        12
# 55     Functional            <class 'str'>         1460         7
# 56     Fireplaces    <class 'numpy.int64'>         1460         4
# 57    FireplaceQu            <class 'str'>          770         5
# 58     GarageType            <class 'str'>         1379         6
# 59    GarageYrBlt  <class 'numpy.float64'>         1379        97
# 60   GarageFinish            <class 'str'>         1379         3
# 61     GarageCars    <class 'numpy.int64'>         1460         5
# 62     GarageArea    <class 'numpy.int64'>         1460       441
# 63     GarageQual            <class 'str'>         1379         5
# 64     GarageCond            <class 'str'>         1379         5
# 65     PavedDrive            <class 'str'>         1460         3
# 66     WoodDeckSF    <class 'numpy.int64'>         1460       274
# 67    OpenPorchSF    <class 'numpy.int64'>         1460       202
# 68  EnclosedPorch    <class 'numpy.int64'>         1460       120
# 69      3SsnPorch    <class 'numpy.int64'>         1460        20
# 70    ScreenPorch    <class 'numpy.int64'>         1460        76
# 71       PoolArea    <class 'numpy.int64'>         1460         8
# 72         PoolQC            <class 'str'>            7         3
# 73          Fence            <class 'str'>          281         4
# 74    MiscFeature            <class 'str'>           54         4
# 75        MiscVal    <class 'numpy.int64'>         1460        21
# 76         MoSold    <class 'numpy.int64'>         1460        12
# 77         YrSold    <class 'numpy.int64'>         1460         5
# 78       SaleType            <class 'str'>         1460         9
# 79  SaleCondition            <class 'str'>         1460         6
# 80      SalePrice    <class 'numpy.int64'>         1460       663
